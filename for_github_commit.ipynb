# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "/content/drive/MyDrive/githubtest/IMP_GCN_jhw"
# Out:
# /content/drive/MyDrive/githubtest/IMP_GCN_jhw

# %%
# !git remote rm origin

# %%
#!echo "IMP_GCN" >> README.md
# !git init
# !git config --global user.email '612gpdnjs@gmail.com'
# !git config --global user.name 'Hyewonon'
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/githubtest/IMP_GCN_jhw/.git/

# %%
# !git remote add origin https://Hyewonon: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@github.com/Hyewonon/IMP_GCN.git
# !git push -u origin main

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main ed4af16] setup
#  35 files changed, 1567 insertions(+), 98177 deletions(-)
#  rewrite Data/movielens_100k/s_adj_mat.npz (89%)
#  rewrite Data/movielens_100k/s_mean_adj_mat.npz (85%)
#  rewrite Data/movielens_100k/s_norm_adj_mat.npz (97%)
#  create mode 100644 "IMP_GCN/IMP_GCN.py\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 IMP_GCN/movielens_100kimpgcn.txt
#  create mode 100644 IMP_GCN/output/movielens_100k/IMP_GCN_pre_IMP_GCN_l3.result
#  create mode 100644 IMP_GCN/output/movielens_100k/IMP_GCN_pre_IMP_GCN_l6.result
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/checkpoint
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-219.data-00000-of-00001
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-219.index
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-219.meta
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-239.data-00000-of-00001
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-239.index
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l3/64-64-64/l0.001_r0.0001/weights-239.meta
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/checkpoint
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-19.data-00000-of-00001
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-19.index
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-19.meta
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-429.data-00000-of-00001
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-429.index
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-429.meta
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-439.data-00000-of-00001
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-439.index
#  create mode 100644 IMP_GCN/weights/movielens_100k/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-439.meta
#  rewrite for_github_commit.ipynb (96%)
# Counting objects: 50, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (45/45), done.
# Writing objects: 100% (50/50), 11.59 MiB | 7.01 MiB/s, done.
# Total 50 (delta 19), reused 0 (delta 0)
# remote: Resolving deltas: 100% (19/19), completed with 12 local objects.
# To https://github.com/Hyewonon/imp_gcn_lab.git
#    42e89a1..ed4af16  main -> main
