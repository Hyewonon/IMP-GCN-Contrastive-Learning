# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
cd '/content/drive/MyDrive/githubtest/IMP_GCN_jhw'
# Out:
# /content/drive/MyDrive/githubtest/IMP_GCN_jhw

# %%
# !git remote rm origin

# %%
# !echo "IMP_GCN_lab" >> README.md
# !git init
# !git config --global user.email '612gpdnjs@gmail.com'
# !git config --global user.name 'Hyewonon'
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://Hyewonon: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@github.com/Hyewonon/imp_gcn_lab.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/githubtest/IMP_GCN_jhw/.git/
# [main 86582f0] first commit
#  1 file changed, 1 insertion(+)
# fatal: remote origin already exists.
# Enumerating objects: 116, done.
# Counting objects: 100% (116/116), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (107/107), done.

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main 88c1f02] setup
#  36 files changed, 144278 insertions(+), 14 deletions(-)
#  create mode 100644 Data/KS10/s_adj_mat.npz
#  create mode 100644 Data/KS10/s_mean_adj_mat.npz
#  create mode 100644 Data/KS10/s_norm_adj_mat.npz
#  create mode 100644 Data/KS10/s_pre_adj_mat.npz
#  create mode 100644 Data/gowalla/s_adj_mat.npz
#  create mode 100644 Data/gowalla/s_mean_adj_mat.npz
#  create mode 100644 Data/gowalla/s_norm_adj_mat.npz
#  create mode 100644 Data/gowalla/s_pre_adj_mat.npz
#  create mode 100644 Data/movielens_100k/s_adj_mat.npz
#  create mode 100644 Data/movielens_100k/s_mean_adj_mat.npz
#  create mode 100644 Data/movielens_100k/s_norm_adj_mat.npz
#  create mode 100644 Data/movielens_100k/s_pre_adj_mat.npz
#  create mode 100644 Data/movielens_100k/test.txt
#  create mode 100644 Data/movielens_100k/train.txt
#  create mode 100644 IMP_GCN/KS10impgcn.txt
#  create mode 100644 IMP_GCN/gowallaimpgcn.txt
#  create mode 100644 IMP_GCN/utility/__pycache__/batch_test.cpython-38.pyc
# ...
