# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "/content/drive/MyDrive/githubtest/IMP_GCN_jhw"
# Out:
# /content/drive/MyDrive/githubtest/IMP_GCN_jhw

# %%
# !git remote rm origin

# %%
#!echo "IMP_GCN" >> README.md
# !git init
# !git config --global user.email '612gpdnjs@gmail.com'
# !git config --global user.name 'Hyewonon'
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/githubtest/IMP_GCN_jhw/.git/
# ^C

# %%
# !git remote add origin https://Hyewonon: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@github.com/Hyewonon/IMP_GCN.git
#!git push -u origin main
# !git push --set-upstream origin main
# Out:
# fatal: remote origin already exists.
# To https://github.com/Hyewonon/imp_gcn_lab.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://Hyewonon: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@github.com/Hyewonon/imp_gcn_lab.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main e1e2101] setup
#  7 files changed, 2823 insertions(+), 2823 deletions(-)
#  delete mode 100644 IMP_GCN/weights/KS10/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-39.index
#  rename IMP_GCN/weights/KS10/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/{weights-39.data-00000-of-00001 => weights-49.data-00000-of-00001} (70%)
#  create mode 100644 IMP_GCN/weights/KS10/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/weights-49.index
#  rename IMP_GCN/weights/KS10/IMP_GCN_pre_IMP_GCN_l6/64-64-64-64-64-64/l0.001_r0.0001/{weights-39.meta => weights-49.meta} (100%)
#  rewrite for_github_commit.ipynb (82%)
# fatal: The current branch main has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin main
